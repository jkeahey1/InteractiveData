# %% [markdown]
# # Julia Keahey
# **What I am looking to get out of this class:**
# 1. Expand my technical knowledge of data analytics (currently in my work I use a dashboard generated by *Sprout Social*)
# ![Image](https://media.sproutsocial.com/uploads/2018/11/Sprout-Press-Sprout-Social.png)
# 2. Learn Python
# 3. Have a more positive relationship with coding
#
# ##### I'm new to Python but I'm excited to learn!

# %%
var1 = 94
var2 = 7

# %%
var1 + var2
# Out:
# 101

# %%
def function1():
    print("Julia")                
    return "is excited to learn coding" 

print(function1())
# Out:
# Julia is excited to learn coding
# Julia
# is excited to learn coding
